# %% [markdown]
# # Goal of this script :
# -Determine how to exploit voice data
# -Familiarize with librairies for audio signal processing

# %%
import sys, os
import numpy as np
import pandas
import scipy

#signal processing
from scipy.signal import spectrogram
from numpy.fft import fft

#work with audio
from pydub import AudioSegment
from pydub.playback import play
from scipy.io import wavfile
import simpleaudio as sa

#plot librairies
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/klegoff/git_synchronized/Projet_digitale/Script'

# %%
os.chdir('../Data')

# %%
# DATA IMPORT

file = "tedx_viktorovitch.wav" 

#to work with .wavfile : 
samplerate, data = wavfile.read(file)


"""" If we want to work with mp3 file : 
sound = AudioSegment.from_mp3(file)
#play(sound)

# get numerical values
data = np.array(sound.get_array_of_samples())
samplerate = 44100
"""
# Out:
# <ipython-input-4-d7b08f5e9019>:6: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read(file)
# '" If we want to work with mp3 file : \nsound = AudioSegment.from_mp3(file)\n#play(sound)\n\n# get numerical values\ndata = np.array(sound.get_array_of_samples())\nsamplerate = 44100\n'

# %% [markdown]
# # I- Description of the data

# %%
# The data is composed of audio file (.wav or .mp3), sampled à 44100 kHz

print(max(data), min(data)) # range of the amplitude => to normalize / standardize
# Out:
# 28967 -32213

# %%
# glimpse of the numerical signal

time =  np.linspace(0, 1/samplerate, data.shape[0])

plt.plot(time[50000:60000], data[50000:60000], label="Amplitude")

plt.legend()

plt.xlabel("Time [s]")

plt.ylabel("Amplitude")

plt.show()

# %% [markdown]
# # II- Transform data into spectrogram & vizualization

# %%
# we work on a sub sample of the data

N_sec = 0.5 # how short do we need to take ?  (sliding windows of 25ms for ASR)
start_idx = np.random.randint(0, len(data)) # start on random index in the data
end_idx = start_idx + int(N_sec * 44100)

red_data = data[start_idx : end_idx]
#1 second = 44100 values of the numeric array

# %%
f, t, spectrogramme = spectrogram(red_data, samplerate)

#plot the sonor level of the signal (dB), on each frequency
dB = 10 * np.log10(spectrogramme)

plt.pcolormesh(t, f, dB)

plt.ylabel('Frequency [Hz]')

plt.xlabel('Time [sec]')

plt.show()
# Out:
# <ipython-input-8-c81156253096>:6: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, f, dB)

# %%
# play the sub sample of data, from which we computed the spectrogram
sa.play_buffer(red_data, 1, 2, samplerate)

# %% [markdown]
# # III- MFCC feature

# %%
N_sec = 0.025 #50 ms window
start_idx = np.random.randint(0, len(data)) # start on random index in the data
end_idx = start_idx + int(N_sec * 44100)

sample = data[start_idx:end_idx]

# %%
# plot the sample we work on
plt.plot(time[start_idx:end_idx], sample, label="Amplitude")

plt.legend()

plt.xlabel("Time [s]")

plt.ylabel("Amplitude")

plt.show()

# %%
y = fft(sample) # fft results contains complex numbers (which stands for phase + amplitude information, so we need to take the abs value

print(y.max(), y.min()) # show max/min values


plt.plot(abs(y)/len(y))
# Out:
# (175839.3111204817-48408.19800158275j) (-67186.89217490406-79740.74158461744j)

# %%
y.shape
# Out:
# (2205,)

# %%
# implement the MFCC

def compute_mfcc(signal):
    return signal

# %%
from python_speech_features import mfcc

w = mfcc(red_data, samplerate)
# Out:
# WARNING:root:frame length (1103) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.

# %%
tmax, tmin = t[-1], t[0]

# %%
t1 = [tmin + n*(tmax-tmin)/len(w) for n in range(len(w))]

# %%
plt.pcolormesh(t1, f, w)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-482d122ba0ef> in <module>
# ----> 1 plt.pcolormesh(t1, f, w)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2782         vmax=None, shading=None, antialiased=False, data=None,
#    2783         **kwargs):
# -> 2784     __ret = gca().pcolormesh(
#    2785         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2786         vmax=vmax, shading=shading, antialiased=antialiased,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6070         kwargs.setdefault('edgecolors', 'None')
#    6071
# -> 6072         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6073                                             shading=shading)
#    6074         Ny, Nx = X.shape
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _pcolorargs(funcname, shading, *args)
#    5593         if shading == 'flat':
#    5594             if not (ncols in (Nx, Nx - 1) and nrows in (Ny, Ny - 1)):
# -> 5595                 raise TypeError('Dimensions of C %s are incompatible with'
#    5596                                 ' X (%d) and/or Y (%d); see help(%s)' % (
#    5597                                     C.shape, Nx, Ny, funcname))
#
# TypeError: Dimensions of C (29, 13) are incompatible with X (29) and/or Y (129); see help(pcolormesh)

# %%
for i in range(len(f)-1):
    print(f[i+1] - f[i])
# Out:
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
# 172.265625
